# %%
import netallocation as ntl
import matplotlib.pyplot as plt

# %%
n = ntl.test.get_network_ac_dc()
# Out:
# WARNING:pypsa.io:
# Importing PyPSA from older version of PyPSA than current version 0.16.1.
# Please read the release notes at https://pypsa.org/doc/release_notes.html
# carefully to prepare your network for import.
#
# INFO:pypsa.io:Imported network test.nc has buses, carriers, generators, global_constraints, lines, links, loads

# %%
fig = plt.figure(figsize=(9,9))
n.plot(color_geomap=True, line_colors={'Line': 'teal', 'Link': 'indianred'}, flow=n.snapshots[0], 
       line_widths={'Line':.1, 'Link':.1})
# Out:
# (<matplotlib.collections.PatchCollection at 0x7fd6645f8510>,
# ...
#  <matplotlib.collections.LineCollection at 0x7fd666e8be50>)

# %%
ap = ntl.allocate_flow(n, snapshots=n.snapshots[0], method='Average participation')
ap
# Out:
# <xarray.Dataset>
# Dimensions:                 (branch: 11, sink: 9, source: 9)
# Coordinates:
#   * source                  (source) object 'London' 'Norwich' ... 'Norway DC'
#   * sink                    (sink) object 'London' 'Norwich' ... 'Norway DC'
#     snapshot                datetime64[ns] 2015-01-01
#   * branch                  (branch) MultiIndex
#   - component               (branch) object 'Line' 'Line' ... 'Link' 'Link'
#   - branch_i                (branch) object '0' '1' ... 'DC link'
# Data variables:
#     peer_to_peer            (sink, source) float64 0.0 0.0 0.0 ... 1.023e-12 0.0
#     peer_on_branch_to_peer  (branch, source, sink) float64 0.0 0.0 ... 0.0 0.0
# Attributes:
#     method:   Average Participation

# %%
ap.peer_to_peer.T.to_series().round(8)[lambda ds: ds!=0].to_frame()
# Out:
#                        peer_to_peer
# source     sink
# Manchester Manchester    741.982987
# Frankfurt  Bremen        534.340860
#            Frankfurt     398.047847
# Norway     London         35.796244
#            Norwich       415.462564
#            Manchester    115.568453
#            Bremen        105.745518
#            Norway        820.035836
